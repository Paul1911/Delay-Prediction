# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 101)

# %%
df = pd.read_csv('C:/Users/PC Paul/Documents/Dokumente/DATA SCIENCE/Courses/Model_Engineering/Delay-Prediction/data/interim/df_processed.csv',  index_col = 0)

# %%
df
# Out:
#           leg_no            fn_carrier fn_number      dep_ap_sched  \
# 0      272005011  East Carmen Airlines    EC3098     North Gregory
# 1      272009188  East Carmen Airlines    EC3146        Port Bobby
# 2      271984537  East Carmen Airlines    EC2840         Port Ryan
# 3      272025831  East Carmen Airlines    EC3306          Coleland
# 4      272006092  East Carmen Airlines    EC3114  East Melissaberg
# ...          ...                   ...       ...               ...
# 10093  272019792  East Carmen Airlines    EC3244         Youngland
# 10094  271985212  East Carmen Airlines    EC2864          West Ana
# 10095  272010941  East Carmen Airlines    EC3167       East Carmen
# 10096  271982053  East Carmen Airlines    EC2812    South Loriview
# 10097  272011138  East Carmen Airlines    EC3168        North Anna
#
#       arr_ap_sched dep_sched_date       dep_sched_time arr_sched_date  \
# 0      East Carmen     2019-06-01  2022-04-14 00:40:00     2019-06-01
# ...
