# %% [markdown]
# # Scope of this workbook
#
# Here, we want to actually model the whole thing for different datasets.

# %%
# Imports
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

import datetime

from sklearn.ensemble import GradientBoostingRegressor


#Settings
pd.set_option("display.max_rows", 70)
pd.set_option("display.max_columns", 101)

# %% [markdown]
# # full_df_unedited

# %%
full_df_unedited = pd.read_pickle('../data/processed/full_df_unedited.pkl')

# %%
full_df_unedited.dtypes
# Out:
# fn_number                         object
# dep_ap_sched                      object
# arr_ap_sched                      object
# dep_sched_date            datetime64[ns]
# dep_sched_time            datetime64[ns]
# arr_sched_date            datetime64[ns]
# arr_sched_time            datetime64[ns]
# m_offblockdt              datetime64[ns]
# m_onblockdt               datetime64[ns]
# ac_registration_x                 object
# dep_delay                        float64
# Ac Type Code                      object
# trans_time                         int64
# sched_trans_time                   int64
# Crew Group                        object
# TLC_trans                         object
# crew_type_change                  object
# Sched Groundtime                 float64
# Act Groundtime                   float64
# block_time               timedelta64[ns]
# leg                               object
# route                             object
# mingt                            float64
# catering_duration                float64
# pax_boarding_duration            float64
# dtype: object

# %%
full_df_unedited
# Out:
#       fn_number      dep_ap_sched       arr_ap_sched dep_sched_date  \
# 0        EC3098     North Gregory        East Carmen     2019-06-01
# 1        EC3146        Port Bobby        East Carmen     2019-06-01
# 2        EC2840         Port Ryan        East Carmen     2019-06-01
# 3        EC3306          Coleland        East Carmen     2019-06-01
# 4        EC3114  East Melissaberg        East Carmen     2019-06-01
# ...         ...               ...                ...            ...
# 12180    EC3399       East Carmen  Port Courtneytown     2019-06-30
# 12181    EC3431       East Carmen   East Allisontown     2019-06-30
# 12182    EC3077       East Carmen         Lake David     2019-06-30
# 12183    EC3299       East Carmen           Coleland     2019-06-30
# 12184    EC3328  South Haileyberg        East Carmen     2019-06-30
#
#            dep_sched_time arr_sched_date      arr_sched_time  \
# 0     2022-04-22 00:40:00     2019-06-01 2022-04-22 04:30:00
# 1     2022-04-22 02:05:00     2019-06-01 2022-04-22 04:00:00
# 2     2022-04-22 02:20:00     2019-06-01 2022-04-22 03:50:00
# 3     2022-04-22 02:25:00     2019-06-01 2022-04-22 04:00:00
# 4     2022-04-22 02:30:00     2019-06-01 2022-04-22 04:15:00
# ...                   ...            ...                 ...
# 12180 2022-04-22 20:45:00     2019-06-30 2022-04-22 21:25:00
# 12181 2022-04-22 20:45:00     2019-06-30 2022-04-22 21:20:00
# 12182 2022-04-22 21:10:00     2019-06-30 2022-04-22 23:05:00
# 12183 2022-04-22 21:15:00     2019-06-30 2022-04-22 22:50:00
# 12184 2022-04-22 23:15:00     2019-07-01 2022-04-22 04:00:00
#
#              m_offblockdt         m_onblockdt ac_registration_x  dep_delay  \
# 0     2019-06-01 00:43:00 2019-06-01 04:12:00            ECLBSX        3.0
# 1     2019-06-01 01:58:00 2019-06-01 03:40:00            ECLWHX       -7.0
# 2     2019-06-01 02:24:00 2019-06-01 03:57:00            ECLGLX        4.0
# 3     2019-06-01 02:28:00 2019-06-01 03:49:00            ECLBMX        3.0
# 4     2019-06-01 03:02:00 2019-06-01 04:43:00            ECLGNX       32.0
# ...                   ...                 ...               ...        ...
# 12180 2019-06-30 20:59:00 2019-06-30 21:46:00            ECLGJX       14.0
# 12181 2019-06-30 21:02:00 2019-06-30 21:46:00            ECLWJX       17.0
# 12182 2019-06-30 21:27:00 2019-06-30 23:37:00            ECLGHX       17.0
# 12183 2019-06-30 21:35:00 2019-06-30 23:00:00            ECLBFX       20.0
# 12184 2019-06-30 23:19:00 2019-07-01 04:01:00            ECLBOX        4.0
#
#       Ac Type Code  trans_time  sched_trans_time Crew Group  \
# 0              320           0                 0      Start
# 1              E95           0                 0      Start
# 2              DH4           0                 0      Start
# 3              320           0                 0      Start
# 4              DH4           0                 0      Start
# ...            ...         ...               ...        ...
# 12180          DH4          27                35          A
# 12181          E95          38                80          A
# 12182          DH4           0                 0      Start
# 12183          320           0                 0      Start
# 12184          320           0                 0      Start
#
#                                                TLC_trans crew_type_change  \
# 0      ['Jason Brown_nan_nan_nan_cp', 'Jacob Stein_na...               []
# 1      ['Scott Baker_nan_nan_nan_cp', 'Ruth Hoffman_n...               []
# 2      ['Cory Cooper_nan_nan_nan_ca', 'Morgan Foster_...               []
# 3      ['Anne Davis_nan_nan_nan_ca', 'Miss Amanda Har...               []
# 4      ['Renee Fisher_nan_nan_nan_ca', 'Rebecca Castr...               []
# ...                                                  ...              ...
# 12180  ['Derek Sweeney_372_27_35_cp', 'John Hardin_37...               []
# 12181  ['Linda Davidson_355_38_80_cp', 'Lisa Wilson_3...               []
# 12182  ['Andre Leblanc_nan_nan_nan_cp', 'Ronald Shaff...               []
# 12183  ['Paul Murray_nan_nan_nan_ca', 'James Lee_nan_...               []
# 12184  ['Alicia Hansen_nan_nan_nan_ca', 'Charles Mart...               []
#
#        Sched Groundtime  Act Groundtime      block_time  \
# 0                 235.0           268.0 0 days 03:29:00
# 1                 130.0           189.0 0 days 01:42:00
# 2                 185.0           196.0 0 days 01:33:00
# 3                 145.0           175.0 0 days 01:21:00
# 4                  35.0            21.0 0 days 01:41:00
# ...                 ...             ...             ...
# 12180               NaN             NaN 0 days 00:47:00
# 12181               NaN             NaN 0 days 00:44:00
# 12182               NaN             NaN 0 days 02:10:00
# 12183               NaN             NaN 0 days 01:25:00
# 12184               NaN             NaN 0 days 04:42:00
#
#                                  leg                          route  mingt  \
# 0          North Gregory-East Carmen      East Carmen-North Gregory    NaN
# 1             Port Bobby-East Carmen         East Carmen-Port Bobby    NaN
# 2              Port Ryan-East Carmen          East Carmen-Port Ryan    NaN
# 3               Coleland-East Carmen           Coleland-East Carmen    NaN
# 4       East Melissaberg-East Carmen   East Carmen-East Melissaberg   35.0
# ...                              ...                            ...    ...
# 12180  East Carmen-Port Courtneytown  East Carmen-Port Courtneytown    NaN
# 12181   East Carmen-East Allisontown   East Allisontown-East Carmen    NaN
# 12182         East Carmen-Lake David         East Carmen-Lake David    NaN
# 12183           East Carmen-Coleland           Coleland-East Carmen    NaN
# 12184   South Haileyberg-East Carmen   East Carmen-South Haileyberg    NaN
#
#        catering_duration  pax_boarding_duration
# 0                    NaN                    NaN
# 1                    NaN                    NaN
# 2                    NaN                    NaN
# 3                    NaN                    NaN
# 4                   26.0                   26.0
# ...                  ...                    ...
# 12180                NaN                    NaN
# 12181                NaN                    NaN
# 12182                NaN                    NaN
# 12183                NaN                    NaN
# 12184                NaN                    NaN
#
# [12185 rows x 25 columns]

# %%
# For the moment, let's in this step drop all variables we will not use. ToDo: Check which step is the best step to do that
columns_to_drop = [
    'fn_number',
    'TLC_trans',
    'catering_duration'
]
